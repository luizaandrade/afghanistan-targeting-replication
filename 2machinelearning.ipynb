# %% [markdown]
# # Notebook 2: Machine Learning Models
# Includes replication code for:
# - Table S2
# - Table S3
# - Table S4
# - Table S6
# - Table S7

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import r2_score, roc_auc_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_curve, confusion_matrix
from sklearn.linear_model import SGDClassifier, SGDRegressor, LogisticRegression
from sklearn.model_selection import cross_validate, KFold, StratifiedKFold, GridSearchCV, cross_val_predict
from sklearn.base import BaseEstimator, TransformerMixin, clone
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.base import clone
from lightgbm import LGBMRegressor, LGBMClassifier
from joblib import dump, load

# %%
def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('data/interim_analysis_datasets/merged_household.csv')
x = df[df.columns[28:]].copy()
xcolumns = x.columns
ids = df['hhid']

# %% [markdown]
# ### Define Models

# %%
class DropMissing(TransformerMixin, BaseEstimator):

    def __init__(self, cols_to_check, colnames, threshold=None, variance_threshold=None):
        self.cols_to_check = cols_to_check
        self.colnames = colnames
        self.threshold = threshold
        self.variance_threshold = variance_threshold
        self.columns_ = None

    def fit(self, X, y=None):
        X = pd.DataFrame(X, columns=self.colnames)
        self.columns_ = X.columns
        missing = X[self.cols_to_check].isna().mean()
        self.missing_frac = missing
        var = X[self.cols_to_check].var()
        self.variance = var
        self.cols_to_drop = missing[(missing > self.threshold) | (var < self.variance_threshold)].index
        self.cols_to_keep = missing[(missing <= self.threshold) & (var >= self.variance_threshold)].index
        return self

    def transform(self, X, y=None):
        X = pd.DataFrame(X, columns=self.colnames)
        return X.drop(self.cols_to_drop.values, axis=1)

    def get_feature_names(self):
        return list(set(self.columns_) - set(self.cols_to_drop))

# %%
class Winsorizer(TransformerMixin, BaseEstimator):
    def __init__(self, limits=None):
        self.limits = limits

    def fit(self, X, y=None):
        X = pd.DataFrame(X)
        if self.limits is None:
            self.limits = (0.01, 0.99)
        elif isinstance(self.limits, float):
            self.limits = (self.limits, 1 - self.limits)

        columns = [c for c in X.columns if pd.api.types.is_numeric_dtype(X[c])]
        threshold_dict = {}

        for column in columns:
            low, high = X[column].quantile(self.limits)
            threshold_dict[column] = (low, high)

        self.columns_ = columns
        self.threshold_dict_ = threshold_dict

        return self

    def transform(self, X, y=None):
        X = pd.DataFrame(X)
        X_t = X.copy()
        def trim(x, low, high):
            if pd.isna(x):
                return x
            else:
                x = low if x < low else x
                x = high if x > high else x
                return x
        trim_vec = np.vectorize(trim)

        for column, tup in self.threshold_dict_.items():
            X_t[column] = trim_vec(X_t[column], *tup)

        return X_t

    def get_feature_names(self, feature_in=None):
        return self.columns_

# %%
# NOTE: To make thing run faster, I've used reduced hyperparameter grids for this replication code (since the
# synthetic data is uncorrelated with the target, hyperparameter searches won't improve performance anyway). 
# The full hyperparameter grids used in the paper are commented out. Running with the full hyperparameter grids
# on the synthetic data takes several hours on a server with 56 CPUs.

#logistic_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#                 'dropmissing__threshold':[.5, .8, 1],
#                 'dropmissing__variance_threshold':[0, 0.01, 0.1]}

logistic_grid = {'winsorizer__limits':[(0., 1.)],
                 'dropmissing__threshold':[.5],
                 'dropmissing__variance_threshold':[0]}

logistic = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
                     ('winsorizer', Winsorizer()), 
                     ('imputer', SimpleImputer(strategy='mean')),
                     ('scaler', MinMaxScaler()),
                     ('model', SGDClassifier(loss='log', penalty='l1', alpha=0.000000000000001, n_jobs=1, 
                                             random_state=1))])

#lasso_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#              'dropmissing__threshold':[.5, .8, 1],
#              'dropmissing__variance_threshold':[0, 0.01, 0.1],
#              'model__alpha':[.00001, .0001, .001, .01, .1, 1, 10, 100]}

lasso_grid = {'winsorizer__limits':[(0., 1.)],
              'dropmissing__threshold':[.5],
              'dropmissing__variance_threshold':[0.1],
              'model__alpha':[1]}

lasso = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
                  ('winsorizer', Winsorizer()), 
                  ('imputer', SimpleImputer(strategy='mean')),
                  ('scaler', MinMaxScaler()),
                  ('model', SGDClassifier(loss='log', penalty='l1', n_jobs=1, random_state=1))])

#rf_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#           'dropmissing__threshold':[.5, .8, 1],
#           'dropmissing__variance_threshold':[0, 0.01, 0.1],
#           'model__n_estimators':[50, 100, 200],
#           'model__max_depth':[2, 4, 6, 8]}

rf_grid = {'winsorizer__limits':[(0., 1.)],
           'dropmissing__threshold':[.5],
           'dropmissing__variance_threshold':[0],
           'model__n_estimators':[50],
           'model__max_depth':[2]}

rf = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
               ('winsorizer', Winsorizer()), 
               ('imputer', SimpleImputer(strategy='mean')),
               ('scaler', MinMaxScaler()),
               ('model', RandomForestClassifier(n_jobs=-1, random_state=1, criterion='entropy'))])

#lgbm_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#             'dropmissing__threshold':[.5, .8, 1],
#             'dropmissing__variance_threshold':[0, 0.01, 0.1],
#             'model__n_estimators':[50, 100, 200],
#             'model__min_data_in_leaf':[20, 50, 100], 
#             'model__num_leaves':[5, 10],
#             'model__learning_rate':[0.05, 0.075]}

lgbm_grid = {'winsorizer__limits':[(0., 1.)],
             'dropmissing__threshold':[.5],
             'dropmissing__variance_threshold':[0],
             'model__n_estimators':[50],
             'model__min_data_in_leaf':[20], 
             'model__num_leaves':[5],
             'model__learning_rate':[0.05]}

lgbm = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)), 
                ('winsorizer', Winsorizer()), 
                ('model', LGBMClassifier(n_jobs=1, random_state=1))])
    
regression_models = {
    'logistic':SGDRegressor(loss='squared_loss', penalty='l1', alpha=0.000000000000001, random_state=1),
    'lasso':SGDRegressor(loss='squared_loss', penalty='l1', random_state=1),
    'rf':RandomForestRegressor(n_jobs=-1, random_state=1),
    'lgbm':LGBMRegressor(n_jobs=-1, random_state=1)
}

# %% [markdown]
# ### Run Models

# %%
for outcome, method in [('ultra_poor', 'classification'), ('asset_index', 'regression'), 
                        ('log_expend', 'regression'), ('below_poverty_line', 'classification'), 
                        ('cwr_group', 'regression')]:
    for base_model, grid, label in [(logistic, logistic_grid, 'logistic'), (lasso, lasso_grid, 'lasso'), 
                                     (rf, rf_grid, 'rf'), (lgbm, lgbm_grid, 'lgbm')]:

        # Define y variable
        y = df[outcome]

        # Get file names
        print('Running ' + outcome + ', ' + label + '...')
        base_folder = 'results/simulations/' + outcome + '/' + label + '/'
        if not os.path.isdir(base_folder[:-1]):
            os.mkdir(base_folder[:-1])

        # Use classification if a classification outcome, else use regression
        base_model = clone(base_model)
        if method == 'classification':
            inner_strat = StratifiedKFold(n_splits=3, shuffle=True, random_state=15)
            outer_strat = StratifiedKFold(n_splits=10, shuffle=True, random_state=14) 
            scoring = 'roc_auc'
            scoring_method = 'predict_proba'
        else:
            base_model.set_params(model=regression_models[label])
            inner_strat = KFold(n_splits=3, shuffle=True, random_state=15)
            outer_strat = KFold(n_splits=10, shuffle=True, random_state=14)
            scoring = 'r2'
            scoring_method = 'predict'

        # Create grid search object
        model = GridSearchCV(estimator=base_model, param_grid=grid, cv=inner_strat, scoring=scoring, 
                             verbose=10, refit=True)

        # Get predictions out of sample over 10-fold CV and save to file
        yhat = cross_val_predict(model, x, y, method=scoring_method, n_jobs=-1, cv=outer_strat)
        if method == 'classification':
            yhat = yhat[:, 1]
        predictions_df = pd.DataFrame([ids, y, yhat]).T
        predictions_df.columns = ['hhid', 'y', 'yhat']
        predictions_df.to_csv(base_folder + 'predictions.csv', index=False)
        if method == 'classification':
            print((label + ' Score: %.4f') % roc_auc_score(y, yhat))
        else:
            print((label + ' Score: %.4f') % r2_score(y, yhat))

        # Retrain model on all data to save information on hyperparameters and feature importances
        model.n_jobs = -1
        model.verbose = 0
        model.fit(x, y)
        
        # Save the model itself
        dump(model, base_folder + 'model')
        
        # Save the dataframe of tuning results
        resultsdf = pd.DataFrame(model.cv_results_)
        resultsdf.to_csv(base_folder + 'tuning.csv', index=False)
        
        # Save the dataframe of feature importances
        try:
            imports = model.best_estimator_.named_steps['model'].feature_importances_
        except:
            imports = model.best_estimator_.named_steps['model'].coef_
        cols_kept = model.best_estimator_.named_steps['dropmissing'].cols_to_keep
        imports = pd.DataFrame([cols_kept, imports]).T
        imports.columns = ['feature', 'importance']
        imports.to_csv(base_folder + 'feature_importances.csv')
# Out:
# Running ultra_poor, logistic...
# logistic Score: 0.4910
# Running ultra_poor, lasso...
# lasso Score: 0.4988
# Running ultra_poor, rf...
# rf Score: 0.5120
# Running ultra_poor, lgbm...
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.576, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.563, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.585, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.458, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.491, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.498, total=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.430, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.480, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.532, total=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.560, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.481, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.555, total=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.453, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.515, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.499, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.333, total=   1.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.528, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.469, total=   1.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.454, total=   2.3s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.428, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.384, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.457, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.564, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.491, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.539, total=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.473, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.402, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.428, total=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.475, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.450, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.562, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.528, total=   1.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.573, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.468, total=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.499, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.443, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.559, total=   2.3s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.511, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.487, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.527, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.504, total=   2.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.439, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.514, total=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.426, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.420, total=   0.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.469, total=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.513, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.345, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.475, total=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.530, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.558, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.436, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.430, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.383, total=   2.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.527, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.542, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.558, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0) [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# lgbm Score: 0.5000
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# Running asset_index, logistic...
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.451, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.426, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.427, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.499, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.511, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.519, total=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.572, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.581, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.474, total=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.459, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.518, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.567, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.477, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.534, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.496, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.576, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.551, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.536, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.133, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0) logistic Score: -0.1655
# Running asset_index, lasso...
# lasso Score: -0.0072
# Running asset_index, rf...
#
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.503, total=   2.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.495, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.487, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.454, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.484, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.458, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.409, total=   1.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.277, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.166, total=   2.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.368, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.372, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.182, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.266, total=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.001, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.010, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.003, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.007, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.004, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.019, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.024, total=   2.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.044, total=   3.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.016, total=   2.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.013, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.532, total=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.490, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# ...
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.023, total=   3.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.025, total=   2.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.037, total=   2.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.035, total=   2.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.032, total=   3.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.020, total=   3.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.048, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.023, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.010, total=   1.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.041, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.103, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.063, total=   2.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
#
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=-0.532, total=   1.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.003, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.007, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.000, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.000, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.011, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.009, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.020, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.000, total=   0.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.027, total=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.043, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.032, total=   2.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.012, total=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.018, total=   4.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.037, total=   3.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.035, total=   3.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.029, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.022, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.044, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.085, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.043, total=   2.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.065, total=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.074, total=   2.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.073, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.057, total=   2.4s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# lgbm Score: -0.0881
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20

# %% [markdown]
# ### Machine learning from phone data with individual-level matching

# %%
df = pd.read_csv('data/interim_analysis_datasets/merged_individual.csv')
x = df[df.columns[28:]].copy()
xcolumns = x.columns
ids = df['hhid']

# %%
outcome, method = 'ultra_poor', 'classification'
for base_model, grid, label in [(logistic, logistic_grid, 'logistic'), (lasso, lasso_grid, 'lasso'), 
                                 (rf, rf_grid, 'rf'), (lgbm, lgbm_grid, 'lgbm')]:

    # Define y variable
    y = df[outcome]

    # Get file names
    print('Running ' + outcome + ', ' + label + '...')
    base_folder = 'results/simulations/' + outcome + '/individual/' + label + '/'
    if not os.path.isdir(base_folder[:-1]):
        os.mkdir(base_folder[:-1])

    # Use classification if a classification outcome, else use regression
    base_model = clone(base_model)
    if method == 'classification':
        inner_strat = StratifiedKFold(n_splits=3, shuffle=True, random_state=15)
        outer_strat = StratifiedKFold(n_splits=10, shuffle=True, random_state=14) 
        scoring = 'roc_auc'
        scoring_method = 'predict_proba'
    else:
        base_model.set_params(model=regression_models[label])
        inner_strat = KFold(n_splits=3, shuffle=True, random_state=15)
        outer_strat = KFold(n_splits=10, shuffle=True, random_state=14)
        scoring = 'r2'
        scoring_method = 'predict'

    # Create grid search object
    model = GridSearchCV(estimator=base_model, param_grid=grid, cv=inner_strat, scoring=scoring, 
                         verbose=10, refit=True)

    # Get predictions out of sample over 10-fold CV and save to file
    yhat = cross_val_predict(model, x, y, method=scoring_method, n_jobs=-1, cv=outer_strat)
    if method == 'classification':
        yhat = yhat[:, 1]
    predictions_df = pd.DataFrame([ids, y, yhat]).T
    predictions_df.columns = ['hhid', 'y', 'yhat']
    predictions_df.to_csv(base_folder + 'predictions.csv', index=False)
    if method == 'classification':
        print((label + ' Score: %.4f') % roc_auc_score(y, yhat))
    else:
        print((label + ' Score: %.4f') % r2_score(y, yhat))

    # Retrain model on all data to save information on hyperparameters and feature importances
    model.n_jobs = -1
    model.verbose = 0
    model.fit(x, y)

    # Save the model itself
    dump(model, base_folder + 'model')

    # Save the dataframe of tuning results
    resultsdf = pd.DataFrame(model.cv_results_)
    resultsdf.to_csv(base_folder + 'tuning.csv', index=False)

    # Save the dataframe of feature importances
    try:
        imports = model.best_estimator_.named_steps['model'].feature_importances_
    except:
        imports = model.best_estimator_.named_steps['model'].coef_
    cols_kept = model.best_estimator_.named_steps['dropmissing'].cols_to_keep
    imports = pd.DataFrame([cols_kept, imports]).T
    imports.columns = ['feature', 'importance']
    imports.to_csv(base_folder + 'feature_importances.csv')
# Out:
# Running ultra_poor, logistic...
#
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.005, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.006, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.001, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.001, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.002, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.000, total=   1.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.002, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=-0.000, total=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.029, total=   3.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.042, total=   2.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.022, total=   2.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.023, total=   3.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.045, total=   3.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.019, total=   3.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.074, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.060, total=   3.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.081, total=   2.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.155, total=   2.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.015, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.045, total=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.461, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.483, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.417, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.519, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.510, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0) logistic Score: 0.4856
# Running ultra_poor, lasso...
#
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=-0.009, total=   3.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.050, total=   2.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.084, total=   2.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.085, total=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.140, total=   2.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.029, total=   2.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.005, total=   2.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.166, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.010, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.080, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.554, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.451, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.444, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.474, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.528, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.447, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0) lasso Score: 0.5038
# Running ultra_poor, rf...
# rf Score: 0.5388
# Running ultra_poor, lgbm...
#
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.057, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.014, total=   2.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.058, total=   2.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.484, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.486, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.511, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.532, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.546, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.508, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.433, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.421, total=   0.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.464, total=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.557, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.540, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.515, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.531, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.611, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.454, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.449, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.405, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.550, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
#
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.028, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.043, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=-0.096, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.539, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.571, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.451, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.532, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.473, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.474, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.392, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.582, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.492, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.497, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.467, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.455, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.460, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.520, total=   2.7s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.7s finished
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
#
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.514, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.430, total=   1.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.461, total=   0.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.538, total=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.6s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.507, total=   2.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.513, total=   1.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.441, total=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.466, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.531, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.441, total=   1.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.421, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.495, total=   2.8s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.532, total=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.546, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.496, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.473, total=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.430, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.544, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0) [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# lgbm Score: 0.5228
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20

# %% [markdown]
# ### Machine learning with asset data

# %%
df = pd.read_csv('data/interim_analysis_datasets/merged_household.csv')
x = df[[col for col in df.columns if 'asset' in col and col != 'asset_index']].astype('float')
xcolumns = x.columns
ids = df['hhid']

# %%
#logistic_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#                 'dropmissing__threshold':[.5, .8, 1],
#                 'dropmissing__variance_threshold':[0, 0.01, 0.1]}

logistic_grid = {'winsorizer__limits':[(0., 1.)],
                 'dropmissing__threshold':[.5],
                 'dropmissing__variance_threshold':[0]}

logistic = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
                     ('winsorizer', Winsorizer()), 
                     ('imputer', SimpleImputer(strategy='mean')),
                     ('scaler', MinMaxScaler()),
                     ('model', SGDClassifier(loss='log', penalty='l1', alpha=0.000000000000001, n_jobs=1, 
                                             random_state=1))])

#lasso_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#              'dropmissing__threshold':[.5, .8, 1],
#              'dropmissing__variance_threshold':[0, 0.01, 0.1],
#              'model__alpha':[.00001, .0001, .001, .01, .1, 1, 10, 100]}

lasso_grid = {'winsorizer__limits':[(0., 1.)],
              'dropmissing__threshold':[.5],
              'dropmissing__variance_threshold':[0.1],
              'model__alpha':[1]}

lasso = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
                  ('winsorizer', Winsorizer()), 
                  ('imputer', SimpleImputer(strategy='mean')),
                  ('scaler', MinMaxScaler()),
                  ('model', SGDClassifier(loss='log', penalty='l1', n_jobs=1, random_state=1))])

#rf_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#           'dropmissing__threshold':[.5, .8, 1],
#           'dropmissing__variance_threshold':[0, 0.01, 0.1],
#           'model__n_estimators':[50, 100, 200],
#           'model__max_depth':[2, 4, 6, 8]}

rf_grid = {'winsorizer__limits':[(0., 1.)],
           'dropmissing__threshold':[.5],
           'dropmissing__variance_threshold':[0],
           'model__n_estimators':[50],
           'model__max_depth':[2]}

rf = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)),  
               ('winsorizer', Winsorizer()), 
               ('imputer', SimpleImputer(strategy='mean')),
               ('scaler', MinMaxScaler()),
               ('model', RandomForestClassifier(n_jobs=-1, random_state=1, criterion='entropy'))])

#lgbm_grid = {'winsorizer__limits':[(0., 1.), (0.005, .995)],
#             'dropmissing__threshold':[.5, .8, 1],
#             'dropmissing__variance_threshold':[0, 0.01, 0.1],
#             'model__n_estimators':[50, 100, 200],
#             'model__min_data_in_leaf':[20, 50, 100], 
#             'model__num_leaves':[5, 10],
#             'model__learning_rate':[0.05, 0.075]}

lgbm_grid = {'winsorizer__limits':[(0., 1.)],
             'dropmissing__threshold':[.5],
             'dropmissing__variance_threshold':[0],
             'model__n_estimators':[50],
             'model__min_data_in_leaf':[20], 
             'model__num_leaves':[5],
             'model__learning_rate':[0.05]}

lgbm = Pipeline([('dropmissing', DropMissing(cols_to_check=xcolumns, colnames=xcolumns)), 
                ('winsorizer', Winsorizer()), 
                ('model', LGBMClassifier(n_jobs=1, random_state=1))])
    
regression_models = {
    'logistic':SGDRegressor(loss='squared_loss', penalty='l1', alpha=0.000000000000001, random_state=1),
    'lasso':SGDRegressor(loss='squared_loss', penalty='l1', random_state=1),
    'rf':RandomForestRegressor(n_jobs=-1, random_state=1),
    'lgbm':LGBMRegressor(n_jobs=-1, random_state=1)
}

# %%
outcome, method = 'ultra_poor', 'classification'
for base_model, grid, label in [(logistic, logistic_grid, 'logistic'), (lasso, lasso_grid, 'lasso'), 
                                 (rf, rf_grid, 'rf'), (lgbm, lgbm_grid, 'lgbm')]:

    # Define y variable
    y = df[outcome].astype('float')

    # Get file names
    print('Running ' + outcome + ', ' + label + '...')
    base_folder = 'results/simulations/' + outcome + '/asset_data/' + label + '/'
    if not os.path.isdir(base_folder[:-1]):
        os.mkdir(base_folder[:-1])

    # Use classification if a classification outcome, else use regression
    base_model = clone(base_model)
    if method == 'classification':
        inner_strat = StratifiedKFold(n_splits=3, shuffle=True, random_state=15)
        outer_strat = StratifiedKFold(n_splits=10, shuffle=True, random_state=14) 
        scoring = 'roc_auc'
        scoring_method = 'predict_proba'
    else:
        base_model.set_params(model=regression_models[label])
        inner_strat = KFold(n_splits=3, shuffle=True, random_state=15)
        outer_strat = KFold(n_splits=10, shuffle=True, random_state=14)
        scoring = 'r2'
        scoring_method = 'predict'

    # Create grid search object
    model = GridSearchCV(estimator=base_model, param_grid=grid, cv=inner_strat, scoring=scoring, 
                         verbose=10, refit=True)

    # Get predictions out of sample over 10-fold CV and save to file
    yhat = cross_val_predict(model, x, y, method=scoring_method, n_jobs=-1, cv=outer_strat)
    if method == 'classification':
        yhat = yhat[:, 1]
    predictions_df = pd.DataFrame([ids, y, yhat]).T
    predictions_df.columns = ['hhid', 'y', 'yhat']
    predictions_df.to_csv(base_folder + 'predictions.csv', index=False)
    if method == 'classification':
        print((label + ' Score: %.4f') % roc_auc_score(y, yhat))
    else:
        print((label + ' Score: %.4f') % r2_score(y, yhat))

    # Retrain model on all data to save information on hyperparameters and feature importances
    model.n_jobs = -1
    model.verbose = 0
    model.fit(x, y)

    # Save the model itself
    dump(model, base_folder + 'model')

    # Save the dataframe of tuning results
    resultsdf = pd.DataFrame(model.cv_results_)
    resultsdf.to_csv(base_folder + 'tuning.csv', index=False)

    # Save the dataframe of feature importances
    try:
        imports = model.best_estimator_.named_steps['model'].feature_importances_
    except:
        imports = model.best_estimator_.named_steps['model'].coef_
    cols_kept = model.best_estimator_.named_steps['dropmissing'].cols_to_keep
    imports = pd.DataFrame([cols_kept, imports]).T
    imports.columns = ['feature', 'importance']
    imports.to_csv(base_folder + 'feature_importances.csv')
# Out:
# Running ultra_poor, logistic...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   10.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   10.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   10.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   10.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s finished
# logistic Score: 0.5045
# Running ultra_poor, lasso...
#
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.532, total=   1.9s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.502, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.483, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.486, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.561, total=   1.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.508, total=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.413, total=   2.2s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.527, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.498, total=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.470, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.607, total=   2.7s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.571, total=   2.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.434, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.642, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.500, total=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.555, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.457, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.477, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.575, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.520, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.484, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.488, total=   2.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.550, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.327, total=   2.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.444, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.524, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.607, total=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.469, total=   1.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.425, total=   1.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.462, total=   1.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.453, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.506, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.474, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.450, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.403, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.429, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.560, total=   0.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.401, total=   0.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.440, total=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0) lasso Score: 0.4988
# Running ultra_poor, rf...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    9.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s finished
# rf Score: 0.4775
# Running ultra_poor, lgbm...
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
#
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.476, total=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.480, total=   2.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.493, total=   2.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.417, total=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.451, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.434, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.519, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.419, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.530, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.471, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.467, total=   0.4s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.421, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.488, total=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.408, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.466, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.475, total=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.520, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.531, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
#
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.517, total=   1.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.478, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.466, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.549, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.473, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.419, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.541, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.384, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.414, total=   0.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, winsorizer__limits=(0.0, 1.0), score=0.455, total=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.0s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0.1, model__alpha=1, winsorizer__limits=(0.0, 1.0), score=0.500, total=   0.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.471, total=   0.5s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.516, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.441, total=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.496, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.473, total=   0.3s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__max_depth=2, model__n_estimators=50, winsorizer__limits=(0.0, 1.0), score=0.461, total=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.440, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.439, total=   0.1s
# [CV] dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0)
# [CV]  dropmissing__threshold=0.5, dropmissing__variance_threshold=0, model__learning_rate=0.05, model__min_data_in_leaf=20, model__n_estimators=50, model__num_leaves=5, winsorizer__limits=(0.0, 1.0), score=0.514, total=   0.1s[LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# lgbm Score: 0.5297
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20

# %% [markdown]
# ### Table S2

# %%
def format_feature(x):
    if x[:19] == 'balance of contacts':
        x = 'BOC' + x[19:]
    elif x[:21] == 'number of interaction':
        x = 'NOI' + x[21:]
    elif x[:24] == 'interactions per contact':
        x = 'IPC' + x[24:]
    elif x[:27] == 'percent pareto interactions':
        x = 'PPI' + x[27:]
    elif x[:24] == 'percent pareto durations':
        x = 'PPD' + x[24:]
    elif x[:15] == 'interevent time':
        x = 'IT' + x[15:]
    elif x[:13] == 'call duration':
        x = 'CD' + x[13:]
    elif x[:14] == 'response delay':
        x = 'RD' + x[14:]
    elif x[:13] == 'response rate':
        x = 'RR' + x[13:]
    tokenized = x.split(' ')
    for i in range(len(tokenized)):
        if tokenized[i] == 'average':
            tokenized[i] = 'avg'
        elif tokenized[i] == 'weekend':
            tokenized[i] = 'WE'
        elif tokenized[i] == 'weekday':
            tokenized[i] = 'WD'
        elif tokenized[i] == 'allweek':
            tokenized[i] = ''
        elif tokenized[i] == 'allday':
            tokenized[i] = ''
        elif tokenized[i] == 'skewness':
            tokenized[i] = 'skew'
        elif tokenized[i] == 'number':
            tokenized[i] = '#'
        elif tokenized[i] == 'percent':
            tokenized[i] = '%'
        elif tokenized[i] == 'of':
            tokenized[i] = ''
        elif tokenized[i] == 'callandtext':
            tokenized[i] = ''
        elif tokenized[i] == ' ':
            tokenized[i] = ''
        if tokenized[i] not in ['BOC', 'NOI', 'IPC', 'PPI', 'PPD', 'IT', 'CD', 'RD', 'RR', 'WE', 'WD']:
            tokenized[i] = tokenized[i].capitalize()
    return ' '.join(tokenized).replace('  ', ' ')

# %%
importances = pd.read_csv('results/simulations/ultra_poor/lgbm/feature_importances.csv')\
    [['feature', 'importance']]\
    .dropna(subset=['importance'])\
    .sort_values('importance', ascending=False)
importances['feature'] = importances['feature']\
    .apply(lambda x: ', '.join([format_feature(' '.join([s for s in str(x).split('_') if s != ''])).strip()]))
importances[:50].to_csv('results/tables/tables2.csv', index=False)
importances.head()
# Out:
#                      feature  importance
# 37   CD WE Night Call Median           9
# 22        CD Night Call Mean           8
# 16              CD  Call Min           8
# 99                RR Text WD           7
# 145    BOC WD Night Call Std           7

# %% [markdown]
# ### Tables S3, S4, S6, and S7

# %%
# Set up labels
models = ['logistic', 'lasso', 'rf', 'lgbm']
classification_model_labels = ['Logistic (No Penalty)', 'Logistic (L1 Penalty)', 'Random Forest', 
                               'Gradient Boosting']
regression_model_labels = ['Linear Regression', 'LASSO Regression', 'Random Forest', 'Gradient Boosting']

for outcome, method in [('ultra_poor', 'classification'), ('asset_index', 'regression'), 
                        ('log_expend', 'regression'), ('below_poverty_line', 'regression'), 
                        ('cwr_group', 'regression'), ('ultra_poor/individual', 'classification'),
                        ('ultra_poor/asset_data', 'regression')]:

    # Set up table
    table = []
    for m, model in enumerate(models):

        # Model score
        predictions = pd.read_csv('results/simulations/' + outcome + '/' + model + '/predictions.csv')
        if method == 'classification':
            score = roc_auc_score(predictions['y'], predictions['yhat'])
        else:
            score = r2_score(predictions['y'], predictions['yhat'])
        score = round(score, 2)

        # Top features
        importances = pd.read_csv('results/simulations/ultra_poor/' + model + '/feature_importances.csv')\
            [['feature', 'importance']]\
            .dropna(subset=['importance'])\
            .sort_values('importance', ascending=False)\
            .head(5)
        importances['feature'] = importances['feature']\
            .apply(lambda x: ', '.join([format_feature(' '.join([s for s in str(x).split('_') if s != '']))\
                                        .strip()]))
        importances = ', '.join(list(importances['feature']))

        # Append row
        if method == 'classification':
            table.append([regression_model_labels[m], score, importances])
        else:
            table.append([regression_model_labels[m], score, importances])
            
    # Make table, write to file
    table = pd.DataFrame(table)
    table.columns = ['Model', 'r2 or AUC', 'Top Five Features']
    if outcome == 'ultra_poor':
        table.to_csv('results/tables/tables3.csv', index=False)
    elif outcome == 'ultra_poor/asset_data':
        table.to_csv('results/tables/tables4.csv', index=False)
    elif outcome == 'ultra_poor/individual':
        table.to_csv('results/tables/tables6.csv', index=False)
    else:
        table.to_csv('results/tables/tables7_panel' + outcome + '.csv', index=False)
table
# Out:
#                Model  r2 or AUC  \
# 0  Linear Regression      -0.81
# 1   LASSO Regression      -0.01
# 2      Random Forest      -0.01
# 3  Gradient Boosting      -0.01
#
#                                    Top Five Features
# 0                                 Below Poverty Line
# 1                                 Below Poverty Line
# 2  BOC WE Night Call Kurtosis, CD Night Call Mean...
# 3  CD WE Night Call Median, CD Night Call Mean, C...

# %% [markdown]
# ### Combining data sources with machine learning

# %%
# Merge survey data and CDR-based predictions
df = pd.read_csv('data/interim_analysis_datasets/merged_household.csv')\
    [['hhid', 'ultra_poor', 'log_expend', 'asset_index', 'weight']]
predictions = pd.read_csv('results/simulations/ultra_poor/lgbm/predictions.csv')[['hhid', 'yhat']]\
    .rename({'yhat':'cdr'}, axis=1)
df = df.merge(predictions, on='hhid', how='inner')

# Set up model, data, and cross validation
y = df['ultra_poor']
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=13)
model = LogisticRegression(penalty='none', n_jobs=1, random_state=100)

# Try different combinations of data together
for regressors in [['asset_index', 'log_expend'], ['asset_index', 'cdr'], ['log_expend', 'cdr'], 
                   ['asset_index', 'log_expend', 'cdr']]:
    x = df[regressors]
    scores = cross_validate(model, x, y, scoring='roc_auc', cv=cv)
    predictions = cross_val_predict(model, x, y, method='predict_proba', cv=cv)
    df['+'.join(regressors)] = predictions[:, 1]
    
# Write to file for later analysis
df.to_csv('data/interim_analysis_datasets/merged_predictions.csv', index=False)
